# %% [markdown]
# # Electric Vehicle Population Data Analysis
#
# #### By: [Mohamed Mohsen](https://www.linkedin.com/in/mohamedmohsen01/)
#
#
# ## Introduction
# Within this project, we delve into an extensive dataset teeming with information concerning electric vehicles. This dataset encompasses an array of attributes, including VIN, City, State, Model Year, Make, Model, Electric Vehicle Type, Electric Range, Base MSRP, and a host of other pertinent details. The primary aim of this analysis is to extract valuable insights and cultivate a comprehensive understanding of the distinctive traits that define the electric vehicles cataloged within the dataset.
#
# ## Data Overview
# The dataset contains 135,039 entries with 17 columns. Some columns have missing values, such as "County," "Model," "Legislative District," "Vehicle Location," and "Electric Utility." These missing values will need to be handled during data preprocessing.
#
#
# ## Features Interpretability
# 1. VIN (1-10): Partial vehicle identification number consisting of the first 10 digits.
# 2. County: The county where the vehicle is registered.
# 3. City: The city where the vehicle is registered.
# 4. State: The state where the vehicle is registered.
# 5. Postal Code: The postal code of the vehicle registration location
# 6. Model Year: The year the vehicle was manufactured.
# 7. Make: The manufacturer or brand of the vehicle.
# 8. Model: The specific model of the vehicle.
# 9. Electric Vehicle Type: Indicates whether the vehicle is a Battery Electric Vehicle (BEV) or a Plug-in Hybrid Electric Vehicle (PHEV).
# 10. Clean Alternative Fuel Vehicle (CAFV) Eligibility: Indicates if the vehicle is eligible for Clean Alternative Fuel Vehicle benefits.
# 11. Electric Range: The range of the vehicle on a full electric charge.
# 12. Base MSRP: The manufacturer's suggested retail price for the vehicle.
# 13. Legislative District: The legislative district associated with the vehicle registration location.
# 14. DOL Vehicle ID: Unique identifier assigned by the Washington State Department of Licensing.
# 15. Vehicle Location: The precise location of the vehicle.
# 16. Electric Utility: The electric utility company associated with the vehicle.
# 17. 2020 Census Tract: The census tract where the vehicle is registered.
#
#
#
#
# ## Data Collection
# Collected the dataset from Kaggle website
#  - Link to the data source: (https://www.kaggle.com/datasets/rajkumarpandey02/electric-vehicle-population-data)
#
#
# ## Data Understanding
# Conducted an in-depth exploration of the dataset's structure, comprehensively documenting available columns, data types, and referring to the data dictionary for clarification.
#
#
# ## Data Pre-processing and Cleaning
# I improved the dataset's quality through a series of data cleaning techniques to prepare the dataset for analysis:
#
# - Employed strategies such as addressing missing data by considering the type of information that was missing.
# - Optimized performance by converting specific columns to their appropriate data types.
#
#
#
# ## Feature Engineering
# Created new variables from existing data that provided additional insights.
#
#
# ## Exploratory Data Analysis (EDA)
# Exploratory data analysis involves addressing the questions and objectives defined within the scope of this project.
#
#
# ## Descriptive Statistics
# The descriptive statistics reveal that the "Electric Range" exhibits a broad range of values, spanning from 0 to 337, with an approximate mean value of 72.3. Likewise, the "Base MSRP" column also displays a wide range of values, with an approximate mean of 1404.82.
#
# ## Data Visualization
# I employed a range of data visualization techniques to delve into the connections among distinctive features and uncovered any discernible trends or patterns within the dataset. These visualizations took the form of bar plots, histograms, box plots, and scatter plots, enabling us to grasp the dataset more comprehensively.
#
#
# ## Conclusion
# Exploring the data yielded valuable insights into the electric vehicle population data. I uncovered the distribution of various features, pinpointed correlations, and unveiled underlying patterns. The visualizations offered a lucid depiction of data trends, equipping us to make informed choices for subsequent analysis or modeling.

# %% [markdown]
# ![inbox_13364933_cdf43b735468100117dd44a05b80a5e5_Untitled-1024--768px-6.jpg](attachment:inbox_13364933_cdf43b735468100117dd44a05b80a5e5_Untitled-1024--768px-6.jpg)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Importing necessary libraries for data analysis and visualization.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore') # Ignore Warnings

pd.set_option('display.max_columns', None) # display max Columns
pd.set_option('display.max_rows', None)   # display max Rows

# %% [markdown]
# # Data Gathering

# %%
# Importing the dataset from a CSV file.
df=pd.read_csv('D:\Data Analyst Portfolio\Python\Electric Vehicle\Electric_Vehicle_Population_Data.csv')

# %% [markdown]
# #  Data Pre-Processing

# %%
# list of the first five rows
df.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year    Make  \
# 0  5YJ3E1EA0K   Thurston   Tumwater    WA      98512.0        2019   TESLA
# 1  1N4BZ1DV4N     Island    Clinton    WA      98236.0        2022  NISSAN
# 2  5YJ3E1EA0L  Snohomish  Snohomish    WA      98290.0        2020   TESLA
# 3  5YJ3E1EBXL       King    Seattle    WA      98134.0        2020   TESLA
# 4  5YJSA1CP0D  Snohomish    Edmonds    WA      98020.0        2013   TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL 3  Battery Electric Vehicle (BEV)
# 1     LEAF  Battery Electric Vehicle (BEV)
# 2  MODEL 3  Battery Electric Vehicle (BEV)
# 3  MODEL 3  Battery Electric Vehicle (BEV)
# 4  MODEL S  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible           220.0
# 1  Eligibility unknown as battery range has not b...             0.0
# ...

# %%
# list of the last five rows
df.tail()
# Out:
#         VIN (1-10)  County          City State  Postal Code  Model Year  \
# 135033  5YJSA1E29L    King  Yarrow Point    WA      98004.0        2020
# 135034  5YJYGDEE7M    King        Burien    WA      98168.0        2021
# 135035  5YJSA1E51N  Pierce    Gig Harbor    WA      98335.0        2022
# 135036  KM8KMDAF3P   Grant       Ephrata    WA      98823.0        2023
# 135037  1FADP5CU4E  Kitsap  Port Orchard    WA      98366.0        2014
#
#            Make    Model                   Electric Vehicle Type  \
# 135033    TESLA  MODEL S          Battery Electric Vehicle (BEV)
# 135034    TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 135035    TESLA  MODEL S          Battery Electric Vehicle (BEV)
# 135036  HYUNDAI  IONIQ 5          Battery Electric Vehicle (BEV)
# 135037     FORD    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %%
# General overview of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135038 entries, 0 to 135037
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         135038 non-null  object
#  1   County                                             135030 non-null  object
#  2   City                                               135030 non-null  object
#  3   State                                              135038 non-null  object
#  4   Postal Code                                        135030 non-null  float64
#  5   Model Year                                         135038 non-null  int64
#  6   Make                                               135038 non-null  object
#  7   Model                                              134789 non-null  object
# ...

# %%
# # Retrieve the shape of the DataFrame 'df'
df.shape
# Out:
# (135038, 17)

# %%
# Displaying all columns in the dataset
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %%
# calculating number of null values
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 8
# City                                                   8
# State                                                  0
# Postal Code                                            8
# Model Year                                             0
# Make                                                   0
# Model                                                249
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         1
# Base MSRP                                              1
# Legislative District                                 312
# DOL Vehicle ID                                         0
# Vehicle Location                                      10
# Electric Utility                                       8
# ...

# %%
# Create a function to compute summary statistics for each column in a DataFrame

def col_summary(data):
    # Initialize empty lists to store column-wise summary information
    col = []
    n_null = []
    n_unique = []
    unique = []
    duplicated = []
    dType = []

    # Iterate through each column in the input DataFrame 'data'
    for column in data.columns:
        col.append(column)
        n_null.append(data[column].isnull().sum())
        n_unique.append(data[column].nunique())
        unique.append(data[column].unique())
        duplicated.append(data[column].duplicated().sum())
        dType.append(data[column].dtype)

    # Create a dictionary to store the summary data
    summary_data = {
        "Columns": col,
        "Data Type": dType,
        "Null": n_null,
        "Unique": unique,
        "n_unique": n_unique,
        "Duplicated": duplicated
    }

    # Create a DataFrame from the summary_data dictionary
    summary_df = pd.DataFrame(summary_data)

    return summary_df


col_summary(df)
# Out:
#                                               Columns Data Type  Null  \
# 0                                          VIN (1-10)    object     0
# 1                                              County    object     8
# 2                                                City    object     8
# 3                                               State    object     0
# 4                                         Postal Code   float64     8
# 5                                          Model Year     int64     0
# 6                                                Make    object     0
# 7                                               Model    object   249
# 8                               Electric Vehicle Type    object     0
# 9   Clean Alternative Fuel Vehicle (CAFV) Eligibility    object     0
# 10                                     Electric Range   float64     1
# 11                                          Base MSRP   float64     1
# ...

# %%
# Select specific columns from the original DataFrame 'df' and create a new DataFrame 'df_new'
col = ['DOL Vehicle ID','2020 Census Tract','County','Legislative District']
df_new = df[col]

# %%
# Retrieve the shape of the DataFrame 'df_new'
df_new.shape
# Out:
# (135038, 4)

# %%
col_summary(df_new)
# Out:
#                 Columns Data Type  Null  \
# 0        DOL Vehicle ID     int64     0
# 1     2020 Census Tract   float64     8
# 2                County    object     8
# 3  Legislative District   float64   312
#
#                                               Unique  n_unique  Duplicated
# 0  [242565116, 183272785, 112552366, 6336319, 186...    135038           0
# 1  [53067010910.0, 53029972000.0, 53061052502.0, ...      2042      132995
# 2  [Thurston, Island, Snohomish, King, Chelan, Ki...       169      134868
# 3  [22.0, 10.0, 44.0, 11.0, 21.0, 12.0, 38.0, 1.0...        49      134988

# %% [markdown]
# **1. DOL Vehicle ID:** serves as the unique identifier for our dataset.
#
# **2. The VIN (1-10):** this column isn't unique, which might seem counterintuitive. However, it's truncated, with the first 9 digits containing world manufacturer information and vehicle descriptor details, while the 10th digit encodes the model year.
#
# **3.** We've also noticed some missing values, particularly in the model and legislative district columns. We'll address these by either imputing the missing data or dropping these columns later.
#
# **4.** We will exclude the following columns: DOL Vehicle ID, County, Legislative District, and 2020 Census Tract since they aren't relevant for our analysis.

# %%
df1 = df.drop(col,axis=1)
df1.head()
# Out:
#    VIN (1-10)       City State  Postal Code  Model Year    Make    Model  \
# 0  5YJ3E1EA0K   Tumwater    WA      98512.0        2019   TESLA  MODEL 3
# 1  1N4BZ1DV4N    Clinton    WA      98236.0        2022  NISSAN     LEAF
# 2  5YJ3E1EA0L  Snohomish    WA      98290.0        2020   TESLA  MODEL 3
# 3  5YJ3E1EBXL    Seattle    WA      98134.0        2020   TESLA  MODEL 3
# 4  5YJSA1CP0D    Edmonds    WA      98020.0        2013   TESLA  MODEL S
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
# 2  Battery Electric Vehicle (BEV)
# 3  Battery Electric Vehicle (BEV)
# 4  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible           220.0
# 1  Eligibility unknown as battery range has not b...             0.0
# 2            Clean Alternative Fuel Vehicle Eligible           266.0
# ...

# %%
df1.shape
# Out:
# (135038, 13)

# %% [markdown]
# # **Handling Missing Data**

# %%
col_summary(df1)
# Out:
#                                               Columns Data Type  Null  \
# 0                                          VIN (1-10)    object     0
# 1                                                City    object     8
# 2                                               State    object     0
# 3                                         Postal Code   float64     8
# 4                                          Model Year     int64     0
# 5                                                Make    object     0
# 6                                               Model    object   249
# 7                               Electric Vehicle Type    object     0
# 8   Clean Alternative Fuel Vehicle (CAFV) Eligibility    object     0
# 9                                      Electric Range   float64     1
# 10                                          Base MSRP   float64     1
# 11                                   Vehicle Location    object    10
# ...

# %%
# present all rows contain null values in City column
df1[df1['City'].isnull()]
# Out:
#         VIN (1-10) City State  Postal Code  Model Year    Make          Model  \
# 149     1N4AZ0CP1D  NaN    AP          NaN        2013  NISSAN           LEAF
# 116884  JTDKARFP2H  NaN    TX          NaN        2017  TOYOTA    PRIUS PRIME
# 124298  5YJ3E1EBXJ  NaN    CA          NaN        2018   TESLA        MODEL 3
# 126012  5YJYGAEE4M  NaN    KS          NaN        2021   TESLA        MODEL Y
# 126131  5YJRE11B48  NaN    BC          NaN        2008   TESLA       ROADSTER
# 130433  5YJYGDEEXM  NaN    CA          NaN        2021   TESLA        MODEL Y
# 131491  JTDKN3DP5E  NaN    CA          NaN        2014  TOYOTA  PRIUS PLUG-IN
# 131586  5YJ3E1EA5K  NaN    BC          NaN        2019   TESLA        MODEL 3
#
#                          Electric Vehicle Type  \
# 149             Battery Electric Vehicle (BEV)
# 116884  Plug-in Hybrid Electric Vehicle (PHEV)
# 124298          Battery Electric Vehicle (BEV)
# 126012          Battery Electric Vehicle (BEV)
# ...

# %%
# Drop null values in 'City' column
df1 = df1.dropna(subset=['City'])

# %%
# Check if there's still any null values in 'City' column
df1[df1['City'].isnull()]
# Out:
# Empty DataFrame
# Columns: [VIN (1-10), City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Vehicle Location, Electric Utility]
# Index: []

# %%
# Calculate and retrieve the top 10 most common values in the 'Vehicle Location' column.
df['Vehicle Location'].value_counts()[:10]
# Out:
# POINT (-122.12301999999994 47.67668000000003)     3482
# POINT (-122.20263999999997 47.67850000000004)     2382
# POINT (-122.1873 47.82024500000006)               2369
# POINT (-122.20190499999995 47.61385000000007)     2274
# POINT (-122.16936999999996 47.571015000000045)    2192
# POINT (-122.31849999999997 47.679490000000044)    2166
# POINT (-122.2371867 47.58229970000008)            1943
# POINT (-122.15166499999998 47.75855000000007)     1943
# POINT (-122.03132659999994 47.62857820000005)     1929
# POINT (-122.20928499999997 47.71124000000003)     1861
# Name: Vehicle Location, dtype: int64

# %%
# Fill missing values in the 'Vehicle Location' column with the mode (most common value) of that column.
df1['Vehicle Location'] = df1['Vehicle Location'].fillna(df1['Vehicle Location'].mode().iloc[0])

# %%
col_summary(df1)
# Out:
#                                               Columns Data Type  Null  \
# 0                                          VIN (1-10)    object     0
# 1                                                City    object     0
# 2                                               State    object     0
# 3                                         Postal Code   float64     0
# 4                                          Model Year     int64     0
# 5                                                Make    object     0
# 6                                               Model    object   249
# 7                               Electric Vehicle Type    object     0
# 8   Clean Alternative Fuel Vehicle (CAFV) Eligibility    object     0
# 9                                      Electric Range   float64     1
# 10                                          Base MSRP   float64     1
# 11                                   Vehicle Location    object     0
# ...

# %%
# Let's calculate and retrieve the top 10 most common values in the 'Model' column.
df1['Model'].value_counts().head(10)
# Out:
# MODEL 3        25835
# MODEL Y        23575
# LEAF           13019
# MODEL S         7473
# BOLT EV         5419
# VOLT            4881
# MODEL X         4874
# NIRO            2609
# ID.4            2480
# PRIUS PRIME     2472
# Name: Model, dtype: int64

# %% [markdown]
# I believe I should populate this column using an alternative method rather than the most frequently occurring value.

# %%
# Mising data in Model by VIN (1-10)

df1[df1['Model'].isnull()]['VIN (1-10)'].apply(lambda x : x[2:6]).unique()
# Out:
# array(['4ED3'], dtype=object)

# %%
# Filter the DataFrame 'df1' to create a new DataFrame 'df_4ED3' containing rows where the 'VIN (1-10)' column contains the substring '4ED3'

df_4ED3 = df1[df1['VIN (1-10)'].str.contains('4ED3')]

# %%
df_n = df_4ED3[['Model','Model Year','Electric Vehicle Type', 'Make']]

# %%
# Filter the DataFrame 'df_4ED3' to create a new DataFrame named 'model_null' containing rows where the 'Model' column is null (NaN)
model_null = df_4ED3[df_4ED3['Model'].isnull()]

# Group the rows in model_null by 'Model Year' and collect unique values of 'Model' within each group, resulting in a Series year_per_model
year_per_model = model_null.groupby('Model Year')['Model'].unique()

# %%
year_per_model
# Out:
# Model Year
# 2023    [nan]
# Name: Model, dtype: object

# %%
print(df_4ED3['Model'].unique())
print(df_4ED3['Make'].unique())
# Out:
# ['XC40' 'C40' nan]
# ['VOLVO']

# %%
# Group the DataFrame 'df_4ED3' by the 'Model' column and then count the occurrences of each 'Model Year' within each group to get a count of each 'Model Year' per 'Model'
df_4ED3.groupby(['Model'])['Model Year'].value_counts()
# Out:
# Model  Model Year
# C40    2023          152
#        2022          125
# XC40   2022          243
#        2021          242
#        2023            7
# Name: Model Year, dtype: int64

# %% [markdown]
# In 2023, we've identified that the model year with null values is associated with the C40 model.

# %%
# Fill missing values in the 'Model' column with 'C40' 
df1.fillna({'Model':'C40'},inplace = True)

# %%
col_summary(df1)
# Out:
#                                               Columns Data Type  Null  \
# 0                                          VIN (1-10)    object     0
# 1                                                City    object     0
# 2                                               State    object     0
# 3                                         Postal Code   float64     0
# 4                                          Model Year     int64     0
# 5                                                Make    object     0
# 6                                               Model    object     0
# 7                               Electric Vehicle Type    object     0
# 8   Clean Alternative Fuel Vehicle (CAFV) Eligibility    object     0
# 9                                      Electric Range   float64     1
# 10                                          Base MSRP   float64     1
# 11                                   Vehicle Location    object     0
# ...

# %% [markdown]
# now we have completed null value handling

# %%
# Converting the data type from float to integer format for better optimization.
df1['Postal Code'] = df1['Postal Code'].astype(int)

# %% [markdown]
# # **Visualization**

# %%
# Calculate the top 10 most common cities in the DataFrame and store the result in city_10
city_10 = df1['City'].value_counts()[:10]

# Calculate the top 10 most common states in the DataFrame and store the result in state_10
state_10 = df1['State'].value_counts()[:10]

# Calculate the top 10 most common car models in the DataFrame and store the result in model_10
model_10 = df1['Model'].value_counts()[:10]

# Calculate the top 10 most common model years in the DataFrame and store the result in Model_Year_10
Model_Year_10 = df1['Model Year'].value_counts()[:10]

# Calculate the top 10 most common car makes in the DataFrame and store the result in Make_10
Make_10 = df1['Make'].value_counts()[:10]

# Calculate the top 10 most common electric vehicle types in the DataFrame and store the result in Electric_Vehicle_Type_10
Electric_Vehicle_Type_10 = df1['Electric Vehicle Type'].value_counts()[:10]

# Calculate the top 10 most common Clean Alternative Fuel Vehicle (CAFV) eligibility statuses in the DataFrame and store the result in CAFV_10
CAFV_10 = df1['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts()[:10]

# Calculate the top 10 most common electric utility companies in the DataFrame and store the result in Electric_Utility_10
Electric_Utility_10 = df1['Electric Utility'].value_counts()[:10]

# %%
# Create a subplot in a 1x3 grid and select the first subplot (1 row, 3 columns, this is the first one).
plt.figure(figsize=(20, 8))

# Create a bar chart to visualize the top 10 most common cities. 
plt.subplot(1, 3, 1)
plt.bar(city_10.index, city_10.values)
plt.gca().set_title('Top 10 Cities')
plt.xticks(rotation=65)

# Create a bar chart to visualize the top 10 most common states.
plt.subplot(1, 3, 2)
plt.bar(state_10.index, state_10.values)
plt.gca().set_title('Top 10 States')

# Create a bar chart to visualize the top 10 most common Model Name. 
plt.subplot(1, 3, 3)
plt.bar(model_10.index, model_10.values)
plt.gca().set_title('Model Name')
plt.xticks(rotation=65)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 8))

# Create a bar chart to visualize the top 10 most common Model Year.
plt.subplot(1, 3, 1)
plt.bar(Model_Year_10.index, Model_Year_10.values)
plt.gca().set_title('Model Year')

# Create a bar chart to visualize the top 10 most common Electric Vehicle Type.
plt.subplot(1, 3, 2)
plt.bar(Electric_Vehicle_Type_10.index, Electric_Vehicle_Type_10.values)
plt.gca().set_title('Electric Vehicle Type')
plt.xticks(rotation=30)

# Create a bar chart to visualize the top 10 most common Clean Alternative Fuel Vehicle (CAFV) Eligibility.
plt.subplot(1,3,3)
plt.bar(CAFV_10.index, CAFV_10.values)
plt.gca().set_title('Clean Alternative Fuel Vehicle (CAFV) Eligibility')
plt.xticks(rotation=30)


plt.tight_layout()
plt.show()

# %%
# Generate a summary of statistics for the DataFrame 'df1'.
descripe = df1.describe()
descripe
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP
# count  135030.000000  135030.000000   135029.000000  135029.000000
# mean    98171.001577    2019.663075       74.590747    1447.760333
# std      2450.367211       3.001485       98.744034    9680.303568
# min      1730.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2018.000000        0.000000       0.000000
# 50%     98121.000000    2021.000000       21.000000       0.000000
# 75%     98370.000000    2022.000000      150.000000       0.000000
# max     99701.000000    2024.000000      337.000000  845000.000000

# %% [markdown]
# ## Create a heatmap to visualize the correlation matrix of the data

# %%
# Create a heatmap to visualize the correlation matrix of the DataFrame 'df'
sns.set(font_scale=1.0)
plt.figure(figsize=(11, 6))
sns.heatmap(df.corr(), linewidths=0.6, annot=True, fmt='.1f', cmap='coolwarm', cbar=False)
plt.title('Electric Vehicle Correlation', fontsize=16)
plt.xticks(rotation=80, fontsize=12)
plt.yticks(fontsize=12)

plt.show()

# %%
df1.head(3)
# Out:
#    VIN (1-10)       City State  Postal Code  Model Year    Make    Model  \
# 0  5YJ3E1EA0K   Tumwater    WA        98512        2019   TESLA  MODEL 3
# 1  1N4BZ1DV4N    Clinton    WA        98236        2022  NISSAN     LEAF
# 2  5YJ3E1EA0L  Snohomish    WA        98290        2020   TESLA  MODEL 3
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
# 2  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible           220.0
# 1  Eligibility unknown as battery range has not b...             0.0
# 2            Clean Alternative Fuel Vehicle Eligible           266.0
#
#    Base MSRP                               Vehicle Location  \
# 0        0.0  POINT (-122.91310169999997 47.01359260000004)
# 1        0.0  POINT (-122.35936399999997 47.97965520000008)
# 2        0.0  POINT (-122.09150499999998 47.91555500000004)
#
# ...

# %% [markdown]
# ## Create visual representations of columns that depend on other columns.

# %%
# Group the DataFrame 'df1' by the 'City' column and then count the occurrences of each 'Electric Range' value within each group.
df1.groupby('City')['Electric Range'].value_counts().head(10)
# Out:
# City      Electric Range
# Aberdeen  0.0               34
#           53.0               9
#           19.0               7
#           215.0              7
#           21.0               5
#           25.0               5
#           26.0               4
#           220.0              4
#           87.0               3
#           150.0              3
# Name: Electric Range, dtype: int64

# %%
# Generate a bar plot to illustrate the relationship between 'City' and 'Electric Range'
sns.set(style='whitegrid')
df1.groupby('City')['Electric Range'].value_counts().head(10).plot(kind='bar')
plt.show()

# %%
# Compute the percent change over last decade.
model_year_data = df1['Model Year'].value_counts().sort_index(ascending = False).head(11)
decade_change = model_year_data.pct_change(periods=-1) * 100

# %%
# Plotting Percent Change over last decade
plt.figure(figsize=(12,6))
sns.set(style='whitegrid')
plt.plot(decade_change[1:],color='b',marker='o',markerfacecolor='k')
plt.axhline(y=0,color='red',ls='--')
plt.title('% Change over last decade')
plt.xlabel('Year')
plt.ylabel('% Change')

plt.show()

# %%
# select the duration from 2012 to 2023
after_2012 = df1[(df1['Electric Range'] > 0) & (df1['Model Year'] > 2012)]

sns.set(style='whitegrid')

plt.figure(figsize=(15, 8))
sns.boxplot(data=after_2012, x='Model Year', y='Electric Range')
plt.title("Electric Range of Vehicles over last decade")

plt.show()

# %%
# Electric Range is bigger than 0
electric_clean=df1[df1['Electric Range']>0]

plt.figure(figsize=(20,25))
sns.boxplot(electric_clean, x='Electric Range',y ='Make' )
plt.title("Electric Range of Vehicles for Different Makes")

plt.show()

# %%
# Calculate and display the count of values in the 'Clean Alternative Fuel Vehicle (CAFV) Eligibility' column of the DataFrame 'df1'.
df1['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts()
# Out:
# Clean Alternative Fuel Vehicle Eligible                         61217
# Eligibility unknown as battery range has not been researched    56981
# Not eligible due to low battery range                           16832
# Name: Clean Alternative Fuel Vehicle (CAFV) Eligibility, dtype: int64

# %% [markdown]
# We have three labels: Eligible, Not Eligible, and Unknown.

# %%
# Pie chart for CAFV Eligibility
fig, ax = plt.subplots(figsize=(8, 8))

# Sizes and labels
sizes = df1['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts()
labels = 'Eligible', 'Unknown', 'Not Eligible'

# Colors for the pie chart wedges
colors = ['#E84855', '#ff9900','#1e9570']

# Additional parameters for the pie chart
explode = (0, 0, 0.2)  # To explode  wedge
shadow = True         # To add shadows to the wedges
startangle = 90       # To set the starting angle of the chart

# Plot the pie chart
ax.pie(sizes, labels=labels, autopct='%1.1f%%', explode=explode, shadow=shadow,
       startangle=startangle, wedgeprops={'edgecolor': 'black'}, colors=colors)

# Add a circle to make it a donut chart
centre_circle = plt.Circle((0, 0), 0.65, fc='gray')
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures that pie is drawn as a circle.
ax.axis('equal')

# Set the title for the pie chart
ax.set_title('CAFV Eligibility', fontsize=16)

# Display the pie chart
plt.show()

# %% [markdown]
# ## Thank You!
